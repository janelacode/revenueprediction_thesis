# %%
import pickle

# %% [markdown]
# ## Simple SARIMA model summary

# %%
model = pickle.load(open('sarima.model', 'rb'))
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ...
# Dep. Variable:                              Sales   No. Observations:                   84
# Model:             SARIMAX(3, 1, 3)x(0, 1, 3, 12)   Log Likelihood               -1173.674
# Date:                            Thu, 18 May 2023   AIC                           2367.348
# Time:                                    18:04:53   BIC                           2389.975
# Sample:                                01-01-2014   HQIC                          2376.346
#                                      - 12-01-2020
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.3170      0.527     -2.501      0.012      -2.349      -0.285
# ar.L2         -1.1662      0.619     -1.884      0.060      -2.379       0.047
# ...

# %% [markdown]
# ## SARIMA model with log CPI summary

# %%
model = pickle.load(open('sarimax.model', 'rb'))
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ...
# Dep. Variable:                              Sales   No. Observations:                   84
# Model:             SARIMAX(3, 1, 3)x(0, 1, 3, 12)   Log Likelihood               -1173.703
# Date:                            Thu, 18 May 2023   AIC                           2369.407
# Time:                                    18:06:43   BIC                           2394.296
# Sample:                                01-01-2014   HQIC                          2379.304
#                                      - 12-01-2020
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# CPI         1.536e+05      1e-07   1.53e+12      0.000    1.54e+05    1.54e+05
# ar.L1         -1.3830      0.528     -2.621      0.009      -2.417      -0.349
# ...

# %% [markdown]
# ## SARIMA model with vaccine summary

# %%
model = pickle.load(open('sarimax_vaccine.model', 'rb'))
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ...
# Dep. Variable:                              Sales   No. Observations:                   84
# Model:             SARIMAX(3, 1, 3)x(0, 1, 3, 12)   Log Likelihood               -1174.937
# Date:                            Thu, 18 May 2023   AIC                           2371.873
# Time:                                    18:07:11   BIC                           2396.763
# Sample:                                01-01-2014   HQIC                          2381.771
#                                      - 12-01-2020
# Covariance Type:                              opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# vaccine     1.389e+05   6.83e+04      2.034      0.042    5059.572    2.73e+05
# ar.L1         -0.8146      0.519     -1.569      0.117      -1.832       0.203
# ...
